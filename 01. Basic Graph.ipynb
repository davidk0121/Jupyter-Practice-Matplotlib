# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Basic Graph

# %%
x  = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
print(plt.plot(x, y))

# %%
plt.plot(x, y) 
plt.show() # remove the text

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x, y) 
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot([-1, 0, 1], [-5, -1, 2])
